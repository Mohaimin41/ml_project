# %%
import pandas as pd

# %%
df =  pd.read_csv('dataset/downsampled/downsampled_df.csv')

# %%
df.head(10)
# Out:
#    IPV4_SRC_ADDR  L4_SRC_PORT IPV4_DST_ADDR  L4_DST_PORT  PROTOCOL  L7_PROTO  \
# 0    13.58.98.64        40894  172.31.69.25           22         6      92.0
# 1   18.219.32.43        63269  172.31.69.25           80         6       7.0
# 2   18.219.32.43        54574  172.31.69.28           80         6       7.0
# 3  18.217.165.70        44500  172.31.69.25           80         6       7.0
# 4    18.219.5.43        55796  172.31.69.25           80        17       0.0
# 5  18.219.193.20        39898  172.31.69.25           80         6       7.0
# 6  18.219.193.20        45358  172.31.69.25           80         6       7.0
# 7   18.219.32.43        50779  172.31.69.28           80         6       7.0
# 8   18.219.32.43        58284  172.31.69.28           80         6       7.0
# 9   18.221.219.4        35732  172.31.69.25           21         6       1.0
#
#    IN_BYTES  IN_PKTS  OUT_BYTES  OUT_PKTS  ...  TCP_WIN_MAX_IN  \
# ...

# %%
pd.unique(df['Label'])
# Out:
# array([1, 0], dtype=int64)

# %%
df = df.sample(frac=1)

# %%
df.head(10)
# Out:
#           IPV4_SRC_ADDR  L4_SRC_PORT  IPV4_DST_ADDR  L4_DST_PORT  PROTOCOL  \
# 2894752     172.31.69.5        59351     172.31.0.2           53        17
# 3464896   96.69.128.189        57249  172.31.67.126         3389         6
# 3891641    77.50.75.242        53280   172.31.65.73         3389         6
# 3972604    172.31.66.92        61892     172.31.0.2           53        17
# 2574512    69.16.232.48        53689   172.31.66.24         3389         6
# 2317970    195.222.75.1        54422  172.31.65.103         3389         6
# 1613347  18.216.200.189        64070   172.31.69.25           80         6
# 3226994    172.31.66.14        60741     172.31.0.2           53        17
# 1974616      18.219.9.1        51028   172.31.69.28           80         6
# 1886711   52.14.136.135        63655   172.31.69.28           80         6
#
#          L7_PROTO  IN_BYTES  IN_PKTS  OUT_BYTES  OUT_PKTS  ...  \
# 2894752     5.700        68        1        131         1  ...
# ...

# %%
df.to_csv('dataset/downsampled/downsampled_df_shuffled.csv')
